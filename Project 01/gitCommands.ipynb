# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Github/AML
# Out:
# /content/gdrive/My Drive/Github/AML

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Github/AML/.git/

# %%
username = 'jimgrasell'
repository = 'AML'
token = '988f20aac669fe3d06c11a227f7619a08dd70cb9'

# %%
# !git remote remove origin
# !git remote add origin https://{token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# fatal: No such remote: origin
# origin	https://988f20aac669fe3d06c11a227f7619a08dd70cb9@github.com/jimgrasell/AML.git (fetch)
# origin	https://988f20aac669fe3d06c11a227f7619a08dd70cb9@github.com/jimgrasell/AML.git (push)

# %%
# !git config --global user.email 'jgrasell@gmail.com'
# !git config --global user.name 'JimG'

# %%
# !git add .
# !git commit -m 'First Commit'
# Out:
# [master (root-commit) ab19f63] First Commit
#  3 files changed, 1312 insertions(+)
#  create mode 100644 gitCommands.ipynb
#  create mode 100644 titanic.ipynb
#  create mode 100644 train_and_test2.csv

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 12.96 KiB | 1.30 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/jimgrasell/titanic.git
#  * [new branch]      master -> master
