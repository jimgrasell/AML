# %% [markdown]
# # CSC685 Advanced Machine Learning
# ## Project 01 - James Grasell

# %%
import pandas as pd
import requests
import io

# %%
url = "https://raw.githubusercontent.com/jimgrasell/AML/master/Project 01/data/forestfires.csv?token=ABVGZOFEP5FJHSAW5MY6KF3ALP3FG"
download = requests.get(url).content
download
# Out:
# b'404: Not Found'
