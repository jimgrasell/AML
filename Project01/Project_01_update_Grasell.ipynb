# %% [markdown]
# # CSC685 Advanced Machine Learning
# ### Project 01 - James Grasell

# %%
import requests
import io

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split       # used to split the data into training and test sets
from sklearn.linear_model import LinearRegression          # used to fit and predict the linear regression
from sklearn.metrics import mean_squared_error, r2_score   # used to calculate Rsquared, MSE, and RMSE

# %%
# Import data from gitHub data repository

url = "https://raw.githubusercontent.com/jimgrasell/AML/master/Project01/Data/forestfires.csv"
df = pd.read_csv(url)
df.head()    # Verify that the data loaded correctly
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ### Linear Regression Model: Area and Temperature

# %%
# Visualize relationship between independent (X) and dependent (y) variables prior to running the linear regression

df.plot(x='temp', y='area', style='o')
plt.title('Temperature vs Area Burned')
plt.xlabel('Temperature')
plt.ylabel('Area')
plt.show()

# %%
# Select dependent (y) and independent (X) data for analysis
X = df.iloc[:, 8].values
y = df.iloc[:, 12].values

# Split the data into a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Set up and fit the linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train.reshape(-1,1), y_train)

# Generate predicted y values for the test data set
y_pred = lin_reg.predict(X_test.reshape(-1,1))

# Calculate and print Rsquared, MSE and RMSE
print('Rsquared: ', r2_score(y_test, y_pred))
print('MSE: ', mean_squared_error(y_test, y_pred))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred)))

# Create a results dataframe for model comparisons
results_df = pd.DataFrame([['Temp vs Area', r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]],
                          columns=['Model', 'Rsquared', 'MSE', 'RMSE'])
# Out:
# Rsquared:  -0.03179814808172465
# MSE:  1030.1937692725498
# RMSE:  32.096631743417404

# %% [markdown]
# ###Linear Regression Model: Area and Relative Humidity

# %%
# Visualize relationship between independent (X) and dependent (y) variables prior to running the linear regression

df.plot(x='RH', y='area', style='o')
plt.title('Relative Humidity vs Area Burned')
plt.xlabel('RH')
plt.ylabel('Area')
plt.show()

# %%
# Select dependent (y) and independent (X) data for analysis
X = df.iloc[:, 9].values
y = df.iloc[:, 12].values

# Split the data into a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Set up and fit the linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train.reshape(-1,1), y_train)

# Generate predicted y values for the test data set
y_pred = lin_reg.predict(X_test.reshape(-1,1))

# Calculate and print Rsquared, MSE and RMSE
print('Rsquared: ', r2_score(y_test, y_pred))
print('MSE: ', mean_squared_error(y_test, y_pred))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred)))

# Append the results dataframe for model comparisons
results_df = results_df.append(pd.DataFrame([['RH vs Area', r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]],
                                            columns=['Model', 'Rsquared', 'MSE', 'RMSE']), ignore_index=True)
# Out:
# Rsquared:  -0.19006876268744088
# MSE:  494.68335642937285
# RMSE:  22.241478287860563

# %% [markdown]
# ###Linear Regression Model: Area and Wind

# %%
# Visualize relationship between independent (X) and dependent (y) variables prior to running the linear regression

df.plot(x='wind', y='area', style='o')
plt.title('Wind vs Area Burned')
plt.xlabel('Wind')
plt.ylabel('Area')
plt.show()

# %%
# Select dependent (y) and independent (X) data for analysis
X = df.iloc[:, 10].values
y = df.iloc[:, 12].values

# Split the data into a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Set up and fit the linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train.reshape(-1,1), y_train)

# Generate predicted y values for the test data set
y_pred = lin_reg.predict(X_test.reshape(-1,1))

# Calculate and print Rsquared, MSE and RMSE
print('Rsquared: ', r2_score(y_test, y_pred))
print('MSE: ', mean_squared_error(y_test, y_pred))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred)))

# Append the results dataframe for model comparisons
results_df = results_df.append(pd.DataFrame([['Wind vs Area', r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]],
                                            columns=['Model', 'Rsquared', 'MSE', 'RMSE']), ignore_index=True)
# Out:
# Rsquared:  -0.009482639704628149
# MSE:  1324.0298318544146
# RMSE:  36.38722072176459

# %% [markdown]
# ###Linear Regression Model: Area and Rain

# %%
# Visualize relationship between independent (X) and dependent (y) variables prior to running the linear regression

df.plot(x='rain', y='area', style='o')
plt.title('Rain vs Area Burned')
plt.xlabel('Rain')
plt.ylabel('Area')
plt.show()

# %%
# Select dependent (y) and independent (X) data for analysis
X = df.iloc[:, 11].values
y = df.iloc[:, 12].values

# Split the data into a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Set up and fit the linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train.reshape(-1,1), y_train)

# Generate predicted y values for the test data set
y_pred = lin_reg.predict(X_test.reshape(-1,1))

# Calculate and print Rsquared, MSE and RMSE
print('Rsquared: ', r2_score(y_test, y_pred))
print('MSE: ', mean_squared_error(y_test, y_pred))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred)))

# Append the results dataframe for model comparisons
results_df = results_df.append(pd.DataFrame([['Rain vs Area', r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]],
                                            columns=['Model', 'Rsquared', 'MSE', 'RMSE']), ignore_index=True)

# Print the results dataframe for model comparison
print(results_df)
# Out:
# Rsquared:  -0.01518227855558485
# MSE:  11779.241745118621
# RMSE:  108.53221524099939
#           Model  Rsquared           MSE        RMSE
# 0  Temp vs Area -0.031798   1030.193769   32.096632
# 1    RH vs Area -0.190069    494.683356   22.241478
# 2  Wind vs Area -0.009483   1324.029832   36.387221
# 3  Rain vs Area -0.015182  11779.241745  108.532215
